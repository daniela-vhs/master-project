# %% [markdown]
# # PnL Attribution Exercise

# %%
from dates import clean_date
from pricing import Trade, Portfolio
from instruments import Cap, IRS
from market import Market

import pandas as pd

# %%
dates = pd.DatetimeIndex(pd.read_parquet("clean_data/vols.parquet").Date.unique())

# %%
# Rolling Window
